# %% [markdown]
# # Chapter 1
#
# Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from os.path import basename, exists


def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local)


download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkstats2.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkplot.py")
# Out:
# Downloaded thinkstats2.py
# Downloaded thinkplot.py

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/nsfg.py")

download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dct")
download(
    "https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemPreg.dat.gz"
)
# Out:
# Downloaded nsfg.py
# Downloaded 2002FemPreg.dct
# Downloaded 2002FemPreg.dat.gz

# %% [markdown]
# ## Examples from Chapter 1
#
# Read NSFG data into a Pandas DataFrame.

# %%
import nsfg

# %%
preg = nsfg.ReadFemPreg()
preg.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN  ...           0           0        0
# 1       NaN       1.0       NaN  ...           0           0        0
# 2       NaN       3.0       5.0  ...           0           0        0
# 3       NaN       1.0       NaN  ...           0           0        0
# 4       NaN       1.0       NaN  ...           0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %% [markdown]
# Print the column names.

# %%
preg.columns
# Out:
# Index(['caseid', 'pregordr', 'howpreg_n', 'howpreg_p', 'moscurrp', 'nowprgdk',
#        'pregend1', 'pregend2', 'nbrnaliv', 'multbrth',
#        ...
#        'laborfor_i', 'religion_i', 'metro_i', 'basewgt', 'adj_mod_basewgt',
#        'finalwgt', 'secu_p', 'sest', 'cmintvw', 'totalwgt_lb'],
#       dtype='object', length=244)

# %% [markdown]
# Select a single column name.

# %%
preg.columns[1]
# Out:
# 'pregordr'

# %% [markdown]
# Select a column and check what type it is.

# %%
pregordr = preg['pregordr']
type(pregordr)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Print a column.

# %%
pregordr
# Out:
# 0        1
# 1        2
# 2        1
# 3        2
# 4        3
#         ..
# 13588    1
# 13589    2
# 13590    3
# 13591    4
# 13592    5
# Name: pregordr, Length: 13593, dtype: int64

# %% [markdown]
# Select a single element from a column.

# %%
pregordr[0]
# Out:
# np.int64(1)

# %% [markdown]
# Select a slice from a column.

# %%
pregordr[2:5]
# Out:
# 2    1
# 3    2
# 4    3
# Name: pregordr, dtype: int64

# %% [markdown]
# Select a column using dot notation.

# %%
pregordr = preg.pregordr

# %% [markdown]
# Count the number of times each value occurs.

# %%
preg.outcome.value_counts().sort_index()
# Out:
# outcome
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: count, dtype: int64

# %% [markdown]
# Check the values of another variable.

# %%
preg.birthwgt_lb.value_counts().sort_index()
# Out:
# birthwgt_lb
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# Name: count, dtype: int64

# %% [markdown]
# Make a dictionary that maps from each respondent's `caseid` to a list of indices into the pregnancy `DataFrame`.  Use it to select the pregnancy outcomes for a single respondent.

# %%
caseid = 10229
preg_map = nsfg.MakePregMap(preg)
indices = preg_map[caseid]
preg.outcome[indices].values
# Out:
# array([4, 4, 4, 4, 4, 4, 1])

# %% [markdown]
# ## Exercises

# %% [markdown]
# Select the `birthord` column, print the value counts, and compare to results published in the [codebook](https://ftp.cdc.gov/pub/Health_Statistics/NCHS/Dataset_Documentation/NSFG/Cycle6Codebook-Pregnancy.pdf)

# %% [markdown]
# We can also use `isnull` to count the number of nans.

# %%
preg.birthord.isnull().sum()
# Out:
# np.int64(4445)

# %% [markdown]
# Select the `prglngth` column, print the value counts, and compare to results published in the [codebook](https://ftp.cdc.gov/pub/Health_Statistics/NCHS/Dataset_Documentation/NSFG/Cycle6Codebook-Pregnancy.pdf)

# %% [markdown]
# To compute the mean of a column, you can invoke the `mean` method on a Series.  For example, here is the mean birthweight in pounds:

# %%
preg.totalwgt_lb.mean()
# Out:
# np.float64(7.265628457623368)

# %% [markdown]
# Create a new column named <tt>totalwgt_kg</tt> that contains birth weight in kilograms.  Compute its mean.  Remember that when you create a new column, you have to use dictionary syntax, not dot notation.

# %% [markdown]
# `nsfg.py` also provides `ReadFemResp`, which reads the female respondents file and returns a `DataFrame`:

# %%
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemResp.dct")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/2002FemResp.dat.gz")
# Out:
# Downloaded 2002FemResp.dct
# Downloaded 2002FemResp.dat.gz

# %%
resp = nsfg.ReadFemResp()

# %% [markdown]
# `DataFrame` provides a method `head` that displays the first five rows:

# %%
resp.head()
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
# 1    5012        1         5         1            5          5.0     42
# 2   11586        1         5         1            5          5.0     43
# 3    6794        5         5         4            1          5.0     15
# 4     616        1         5         4            1          5.0     20
#
#    age_r  cmbirth  agescrn  ...  pubassis_i      basewgt  adj_mod_basewgt  \
# 0     27      902       27  ...           0  3247.916977      5123.759559
# 1     42      718       42  ...           0  2335.279149      2846.799490
# 2     43      708       43  ...           0  2335.279149      2846.799490
# 3     15     1042       15  ...           0  3783.152221      5071.464231
# 4     20      991       20  ...           0  5341.329968      6437.335772
#
#       finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime   intvlngth
# ...

# %% [markdown]
# Select the `age_r` column from `resp` and print the value counts.  How old are the youngest and oldest respondents?

# %% [markdown]
# We can use the `caseid` to match up rows from `resp` and `preg`.  For example, we can select the row from `resp` for `caseid` 2298 like this:

# %%
resp[resp.caseid==2298]
# Out:
#    caseid  rscrinf  rdormres  rostscrn  rscreenhisp  rscreenrace  age_a  \
# 0    2298        1         5         5            1          5.0     27
#
#    age_r  cmbirth  agescrn  ...  pubassis_i      basewgt  adj_mod_basewgt  \
# 0     27      902       27  ...           0  3247.916977      5123.759559
#
#       finalwgt  secu_r  sest  cmintvw  cmlstyr  screentime   intvlngth
# 0  5556.717241       2    18     1234     1222    18:26:36  110.492667
#
# [1 rows x 3087 columns]

# %% [markdown]
# And we can get the corresponding rows from `preg` like this:

# %%
preg[preg.caseid==2298]
# Out:
#       caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 2610    2298         1        NaN        NaN       NaN       NaN       6.0
# 2611    2298         2        NaN        NaN       NaN       NaN       6.0
# 2612    2298         3        NaN        NaN       NaN       NaN       6.0
# 2613    2298         4        NaN        NaN       NaN       NaN       6.0
#
#       pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 2610       NaN       1.0       NaN  ...           0           0        0
# 2611       NaN       1.0       NaN  ...           0           0        0
# 2612       NaN       1.0       NaN  ...           0           0        0
# 2613       NaN       1.0       NaN  ...           0           0        0
#
#           basewgt  adj_mod_basewgt     finalwgt  secu_p  sest  cmintvw  \
# 2610  3247.916977      5123.759559  5556.717241       2    18      NaN
# 2611  3247.916977      5123.759559  5556.717241       2    18      NaN
# ...

# %% [markdown]
# How old is the respondent with `caseid` 1?

# %% [markdown]
# What are the pregnancy lengths for the respondent with `caseid` 2298?

# %% [markdown]
# What was the birthweight of the first baby born to the respondent with `caseid` 5013?

# %%
df = preg[preg['outcome']==1]
df.head()
# Out:
#    caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0       1         1        NaN        NaN       NaN       NaN       6.0
# 1       1         2        NaN        NaN       NaN       NaN       6.0
# 2       2         1        NaN        NaN       NaN       NaN       5.0
# 3       2         2        NaN        NaN       NaN       NaN       6.0
# 4       2         3        NaN        NaN       NaN       NaN       6.0
#
#    pregend2  nbrnaliv  multbrth  ...  laborfor_i  religion_i  metro_i  \
# 0       NaN       1.0       NaN  ...           0           0        0
# 1       NaN       1.0       NaN  ...           0           0        0
# 2       NaN       3.0       5.0  ...           0           0        0
# 3       NaN       1.0       NaN  ...           0           0        0
# 4       NaN       1.0       NaN  ...           0           0        0
#
#        basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  \
# ...

# %%
df.shape
# Out:
# (9148, 244)

# %%
first_baby = df[df['birthord']==1]
first_baby['group']='First'
first_baby.shape
# Out:
# <ipython-input-26-926261b4a5be>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_baby['group']='First'
# (4413, 245)

# %%
first_baby.head()
# Out:
#     caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0        1         1        NaN        NaN       NaN       NaN       6.0
# 2        2         1        NaN        NaN       NaN       NaN       5.0
# 5        6         1        NaN        NaN       NaN       NaN       6.0
# 8        7         1        NaN        NaN       NaN       NaN       5.0
# 10      12         1        NaN        NaN       NaN       NaN       5.0
#
#     pregend2  nbrnaliv  multbrth  ...  religion_i  metro_i      basewgt  \
# 0        NaN       1.0       NaN  ...           0        0  3410.389399
# 2        NaN       3.0       5.0  ...           0        0  7226.301740
# 5        NaN       1.0       NaN  ...           0        0  4870.926435
# 8        NaN       1.0       NaN  ...           0        0  3409.579565
# 10       NaN       1.0       NaN  ...           0        0  3612.781968
#
#     adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  totalwgt_lb  group
# ...

# %%
other_baby = df[df['birthord']!=1]
other_baby['group']='Other'
other_baby.shape
# Out:
# <ipython-input-28-0a3eb6eab7ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   other_baby['group']='Other'
# (4735, 245)

# %%
import pandas as pd
combined = pd.concat([first_baby, other_baby])
combined.shape
# Out:
# (9148, 245)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.histplot(data=combined, x='prglngth',hue='group', multiple='dodge')
plt.xlabel('Pregnancy Length (weeks)')
plt.ylabel('Frequency')
plt.xlim(20, 50)
plt.title('Pregnancy Length by Birth Order')
plt.show()

# %%
combined['prglngth'].dtype
# Out:
# dtype('int64')

# %%
df.prglngth.mean(),df.prglngth.var(),df.prglngth.std()
# Out:
# (np.float64(38.56055968517709), 7.302662067826851, 2.702343810070593)

# %%
first_baby.prglngth.mean(),first_baby.prglngth.var(),first_baby.prglngth.std()
# Out:
# (np.float64(38.60095173351461), 7.794713509229059, 2.7919014146686947)

# %%
other_baby.prglngth.mean(),other_baby.prglngth.var(),other_baby.prglngth.std()
# Out:
# (np.float64(38.52291446673706), 6.842683519298573, 2.615852350439255)

# %%
first_baby.prglngth.mean()-other_baby.prglngth.mean()
# Out:
# np.float64(0.07803726677754952)
